# %% [markdown]
# # Day 01: Introduction to Python — Python Basics
#
# **Program:** CSIT 2nd Semester
# **Author:** UNIQUE_ADHIKARI
# *Work Done During Class Session with Teacher Guidance*

# %%
# Print a message to the console
print("Hello World!")
# Out:
# Hello World!

# %%
# Check if 20 is greater than 30
if 20 > 30:
    print("correct!")

# %%
# Assign 10 to the variable 'age'
age=10

# Assign 20 to the variable 'Age'
# Python treats 'age' and 'Age' as different variables (case-sensitive)
Age=20

# Print the value stored in 'Age'
print(Age)
# Out:
# 20

# %%
# Assign the same string value to x, y, and z
x=y=z= "Hello There!"

# Print the value stored in z
print(z)
# Out:
# Hello There!

# %%
# Create a tuple containing fruit names
fruits=("apple", "banana", "cherry")

# Print the tuple
print(fruits)
# Out:
# ('apple', 'banana', 'cherry')

# %%
# Create a list containing fruit names
fruits=["apple", "cherry", "banana"]

# Print the list
print(fruits)
# Out:
# ['apple', 'cherry', 'banana']

# %%
# Create a set containing fruit names
# Duplicate values are automatically removed in a set
fruits={"apple", "cherry", "banana", "apple"}

# Print the set
print(fruits)
# Out:
# {'apple', 'cherry', 'banana'}

# %%
# Store different parts of a sentence in variables
x= "Python"
y= " is"
z= " Awesome!"

# Print all variables together
print(x, y, z)
# Out:
# Python  is  Awesome!

# %%
# Create a range of numbers from 0 to 5
# The ending value 6 is not included
range(0,6)
# Out:
# range(0, 6)

# %%
# Create a list containing fruit names
fruits=["apple", "cherry", "banana"]

# Check and return the data type of the variable
type(fruits)
# Out:
# list

# %%
# Loop through numbers from 0 to 5
for i in range(0,6):
    # Print the current value of i
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
# Assign a floating-point number to the variable x
x= 5.2

# Print the value of x
print(x)

# Check and return the data type of x
type(x)
# Out:
# 5.2
# float

# %%
# Convert the value of x to an integer and store it in y
y= int(x)

# Print the value of y
print(y)

# Check and return the data type of y
type(y)
# Out:
# 5
# int

# %%
# Store a sentence in the variable 'a'
a= "Nepal is a beautiful country"

# Print the string excluding the last 7 characters
print(a[:-7])
# Out:
# Nepal is a beautiful

# %%
# Store a sentence in the variable 'a'
a= "      Nepal is a            beautiful country"

# Remove leading and trailing spaces, then print the result
print(a.strip())
# Out:
# Nepal is a            beautiful country
