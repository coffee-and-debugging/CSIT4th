# %% [markdown]
# Calculator using Python
# contactuniqueadhikari@gmail.com

# %%
firstNum = int(input("Enter first number: "))
operation = input("Enter your desired operation (+, -, *, /)")
secondNum = int(input("Enter second number: "))
try:
    if operation == '+':
        print("Addition: ",firstNum + secondNum)
    elif operation == '-':
        print("Subtraction: ",firstNum - secondNum)
    elif operation == '*':
        print("Multiplication: ",firstNum * secondNum)
    else:
        if(secondNum != 0):
            print("Division: ",firstNum/secondNum)
        else:
            print("Division By Zero")
except:
    print("Invalid Operation!")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 firstNum = int(input("Enter first number: "))
#       2 operation = input("Enter your desired operation (+, -, *, /)")
#       3 secondNum = int(input("Enter second number: "))
#       4 try:
#
# ValueError: invalid literal for int() with base 10: ''
